# %% [markdown]
# <a href="https://colab.research.google.com/github/orimejia/Proyecto-AI/blob/main/Proyecto_I_A_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/andresramirez31/ProyectoIA/main/RegularSeasonDetailedResults.csv'
a = pd.read_csv(url)
a.head()
# Out:
#    Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot  Wfgm  Wfga  ...  \
# 0    2003      10   1104      68   1328      62    N      0    27    58  ...
# 1    2003      10   1272      70   1393      63    N      0    26    62  ...
# 2    2003      11   1266      73   1437      61    N      0    24    58  ...
# 3    2003      11   1296      56   1457      50    N      0    18    38  ...
# 4    2003      11   1400      77   1208      71    N      0    30    61  ...
#
#    Lfga3  Lftm  Lfta  Lor  Ldr  Last  Lto  Lstl  Lblk  Lpf
# 0     10    16    22   10   22     8   18     9     2   20
# 1     24     9    20   20   25     7   12     8     6   16
# 2     26    14    23   31   22     9   12     2     5   23
# 3     22     8    15   17   20     9   19     4     3   23
# 4     16    17    27   21   15    12   10     7     1   14
#
# [5 rows x 34 columns]

# %%
b = a.copy()

# %%
a[(a.Season==2013) & (a.Wteam==1104)]
# Out:
#        Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot  Wfgm  Wfga  \
# 49836    2013       4   1104      70   1355      67    H      0    25    52
# 50111    2013      10   1104      65   1333      62    N      0    26    58
# 50157    2013      11   1104      77   1437      55    N      0    25    44
# 50507    2013      18   1104      59   1149      46    H      0    23    57
# 50695    2013      22   1104      75   1249      47    H      0    30    64
# 51430    2013      44   1104      66   1403      62    A      0    23    45
# 51992    2013      61   1104      65   1324      45    H      0    25    48
# 52300    2013      68   1104      68   1397      65    H      0    23    54
# 52492    2013      72   1104      75   1280      43    A      0    31    58
# 52620    2013      75   1104      50   1401      49    H      0    18    41
# 52797    2013      78   1104      59   1246      55    H      0    21    57
# ...

# %%
for i in range(int(len(b) * 0.05)):
    x = np.random.randint(len(b))
    b.loc[x, "Lftm"] = np.nan
    b.loc[x, "Ldr"] = np.nan
    b.loc[x, "Lfga3"] = np.nan

# %%
a.Lftm.iloc[3] = 0
# Out:
# <ipython-input-8-e0be7e740f12>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.Lftm.iloc[3] = 0

# %%
a["Lftm"][3] = 8
# Out:
# <ipython-input-9-2cf518d85fc2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a["Lftm"][3] = 8

# %%
mask = b["Lftm"]

# %%
a.loc[mask,3]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 3
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
mask[3]
# Out:
# 8.0

# %%
b[3, "Lftm"] = 'nan'

# %%
b["Lftm"][3] = 7
# Out:
# <ipython-input-17-06f796cf412c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b["Lftm"][3] = 7

# %%
#b.loc[3, "Lftm"] = 6

# %%
b
# Out:
#        Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot  Wfgm  Wfga  \
# 0        2003      10   1104      68   1328      62    N      0    27    58
# 1        2003      10   1272      70   1393      63    N      0    26    62
# 2        2003      11   1266      73   1437      61    N      0    24    58
# 3        2003      11   1296      56   1457      50    N      0    18    38
# 4        2003      11   1400      77   1208      71    N      0    30    61
# ...       ...     ...    ...     ...    ...     ...  ...    ...   ...   ...
# 76631    2017     132   1276      71   1458      56    N      0    27    48
# 76632    2017     132   1343      71   1463      59    N      0    25    52
# 76633    2017     132   1348      70   1433      63    N      0    24    54
# 76634    2017     132   1374      71   1153      56    N      0    26    52
# 76635    2017     132   1407      59   1402      53    N      0    21    60
#
# ...

# %%
b['Numot'] = pd.Categorical(b.Numot)

# %%
b['Daynum'] = pd.Categorical(b.Daynum)

# %%
k = b.isna().sum()

# %%
k[k!=0]
# Out:
# Lfga3    3739
# Lftm     3739
# Ldr      3739
# dtype: int64

# %%
k
# Out:
# Season       0
# Daynum       0
# Wteam        0
# Wscore       0
# Lteam        0
# Lscore       0
# Wloc         0
# Numot        0
# Wfgm         0
# Wfga         0
# Wfgm3        0
# Wfga3        0
# Wftm         0
# Wfta         0
# Wor          0
# Wdr          0
# Wast         0
# Wto          0
# Wstl         0
# Wblk         0
# Wpf          0
# Lfgm         0
# Lfga         0
# Lfgm3        0
# Lfga3     3739
# Lftm      3739
# Lfta         0
# Lor          0
# Ldr       3739
# Last         0
# Lto          0
# Lstl         0
# Lblk         0
# Lpf          0
# dtype: int64

# %%
b[b.Season==2006]
# Out:
#        Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot  Wfgm  Wfga  \
# 13862    2006       8   1165      75   1384      54    N      0    24    54
# 13863    2006       8   1393      68   1126      37    H      0    21    44
# 13864    2006       9   1107      90   1324      73    N      0    35    62
# 13865    2006       9   1126      63   1384      52    N      1    22    59
# 13866    2006       9   1196      80   1389      51    H      0    29    54
# ...       ...     ...    ...     ...    ...     ...  ...    ...   ...   ...
# 18614    2006     132   1181      78   1130      76    N      0    25    50
# 18615    2006     132   1196      49   1376      47    N      0    20    41
# 18616    2006     132   1234      67   1326      60    N      0    26    55
# 18617    2006     132   1242      80   1400      68    N      0    27    61
# 18618    2006     132   1322      95   1358      87    H      0    32    64
#
# ...

# %%
pd.set_option("display.max_rows", 50)

# %%
b["Numot"]
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 76631    0
# 76632    0
# 76633    0
# 76634    0
# 76635    0
# Name: Numot, Length: 76636, dtype: category
# Categories (7, int64): [0, 1, 2, 3, 4, 5, 6]

# %%
b["Daynum"]
# Out:
# 0         10
# 1         10
# 2         11
# 3         11
# 4         11
#         ...
# 76631    132
# 76632    132
# 76633    132
# 76634    132
# 76635    132
# Name: Daynum, Length: 76636, dtype: category
# Categories (133, int64): [0, 1, 2, 3, ..., 129, 130, 131, 132]

# %%
b["Wloc"] = pd.Categorical(b.Wloc)

# %%
b["Wloc"]
# Out:
# 0        N
# 1        N
# 2        N
# 3        N
# 4        N
#         ..
# 76631    N
# 76632    N
# 76633    N
# 76634    N
# 76635    N
# Name: Wloc, Length: 76636, dtype: category
# Categories (3, object): ['A', 'H', 'N']

# %%
len(b)
# Out:
# 76636

# %%
b
# Out:
#        Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot  Wfgm  Wfga  \
# 0        2003      10   1104      68   1328      62    N      0    27    58
# 1        2003      10   1272      70   1393      63    N      0    26    62
# 2        2003      11   1266      73   1437      61    N      0    24    58
# 3        2003      11   1296      56   1457      50    N      0    18    38
# 4        2003      11   1400      77   1208      71    N      0    30    61
# ...       ...     ...    ...     ...    ...     ...  ...    ...   ...   ...
# 76631    2017     132   1276      71   1458      56    N      0    27    48
# 76632    2017     132   1343      71   1463      59    N      0    25    52
# 76633    2017     132   1348      70   1433      63    N      0    24    54
# 76634    2017     132   1374      71   1153      56    N      0    26    52
# 76635    2017     132   1407      59   1402      53    N      0    21    60
#
# ...

# %%
c = b[['Wteam','Lteam','Wscore','Lscore']]
c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d7cb4ea640e0> in <cell line: 1>()
# ----> 1 c = b[['Wteam','Lteam','Wscore','Lscore']]
#       2 c
#
# NameError: name 'b' is not defined

# %%
print(c.Lteam.drop_duplicates())
# Out:
# 0        1328
# 1        1393
# 2        1437
# 3        1457
# 4        1208
#          ...
# 50103    1297
# 55192    1213
# 55197    1262
# 55266    1101
# 56014    1230
# Name: Lteam, Length: 355, dtype: int64

# %%
print(c.Wteam)
# Out:
# 0        1104
# 1        1272
# 2        1266
# 3        1296
# 4        1400
#          ...
# 76631    1276
# 76632    1343
# 76633    1348
# 76634    1374
# 76635    1407
# Name: Wteam, Length: 76636, dtype: int64

# %% [markdown]
# Limpieza de datos - Arreglos de datos faltantes

# %%
k = b.isna().sum()

# %%
k[k!=0]
# Out:
# Series([], dtype: int64)

# %%
b["Lfga3"].fillna(b["Lfga3"].mean(), inplace=True)

# %%
b["Lftm"].fillna(b["Lftm"].mean(), inplace=True)

# %%
b["Ldr"].fillna(b["Ldr"].mean(), inplace=True)
